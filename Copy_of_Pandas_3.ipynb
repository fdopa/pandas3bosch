# %% [markdown]
# <a href="https://colab.research.google.com/github/fdopa/pandas3boschdiccionario/blob/main/Copy_of_Pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install gdown
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Descargar datos limpios
# Inventario de vivienda
# Contiene la información que da cuenta de las viviendas y el entorno urbano en el que se están desarrollando.
#
# Año:
# 2017 al 2023
#
# - [Link](https://sniiv.sedatu.gob.mx/Reporte/Datos_abiertos)
# - [Diccionario](https://sniiv.sedatu.gob.mx/Reporte/Datos_abiertos#:~:text=Diccionario%20de%20datos)

# %%
# !git clone https://github.com/javierIA/infonavit.git
# Out:
# fatal: destination path 'infonavit' already exists and is not an empty directory.

# %%
#@title UnirVarios DTF CON EL mismo formato
import pandas as pd
import os

# Create an empty list to store the dataframes
dfs = []

# Iterate over each CSV file in the "Datos" directory
for file_name in os.listdir("infonavit"):
    if file_name.endswith(".csv"):
        file_path = os.path.join("infonavit", file_name)
        df = pd.read_csv(file_path, encoding="latin1")#latin se usa para ñ , acentos
        dfs.append(df)
print(dfs)
merged_df = pd.concat(dfs, ignore_index=True)

# Convert merged dataframe to Parquet format
output_file = "merged_data.parquet"
merged_df.to_parquet(output_file, engine="pyarrow")

print(f"Data converted to Parquet format and saved as {output_file}")
# Out:
# [         año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0       2019    1      1.0  Aguascalientes      NaN  No distribuido
# 1       2019    1      1.0  Aguascalientes      1.0  Aguascalientes
# 2       2019    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3       2019    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4       2019    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...      ...  ...      ...             ...      ...             ...
# 383368  2019   12     32.0       Zacatecas     56.0       Zacatecas
# 383369  2019   12     32.0       Zacatecas     56.0       Zacatecas
# 383370  2019   12     32.0       Zacatecas     56.0       Zacatecas
# 383371  2019   12     32.0       Zacatecas     57.0        Trancoso
# 383372  2019   12     32.0       Zacatecas     57.0        Trancoso
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               4          2      1.0     1   NaN         NaN             NaN
# 1               1          1      2.0     2   1.0         NaN             1.0
# 2               1          1      2.0     2   1.0         NaN             2.0
# 3               1          1      2.0     2   1.0         NaN             3.0
# 4               1          1      2.0     2   1.0         NaN             4.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 383368          4          1      2.0     1   NaN         NaN             5.0
# 383369          4          1      2.0     1   NaN         NaN             6.0
# 383370          4          1      2.0     1   NaN         NaN             6.0
# 383371          1          2      1.0     2   1.0         2.0             4.0
# 383372          2          2      1.0     2   1.0         2.0             3.0
#
#         vivienda_valor  acciones    monto
# 0                  NaN       0.0  96860.0
# 1                  4.0       4.0      0.0
# 2                  3.0       1.0      0.0
# 3                  4.0       1.0      0.0
# 4                  4.0       1.0      0.0
# ...                ...       ...      ...
# 383368             4.0       1.0      0.0
# 383369             4.0       3.0      0.0
# 383370             5.0       3.0      0.0
# 383371             NaN       1.0      0.0
# 383372             1.0       1.0  57534.0
#
# [383373 rows x 16 columns],          año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0       2020    1      1.0  Aguascalientes      1.0  Aguascalientes
# 1       2020    1      1.0  Aguascalientes      1.0  Aguascalientes
# 2       2020    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3       2020    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4       2020    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...      ...  ...      ...             ...      ...             ...
# 357613  2020   12     32.0       Zacatecas     57.0        Trancoso
# 357614  2020   12     32.0       Zacatecas     57.0        Trancoso
# 357615  2020   12     32.0       Zacatecas     57.0        Trancoso
# 357616  2020   12     32.0       Zacatecas     57.0        Trancoso
# 357617  2020   12     32.0       Zacatecas     57.0        Trancoso
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               1          1      2.0     2   1.0         NaN             2.0
# 1               1          1      2.0     2   1.0         NaN             2.0
# 2               1          1      2.0     2   1.0         NaN             6.0
# 3               1          1      2.0     2   1.0         NaN             6.0
# 4               1          1      2.0     2   1.0         1.0             1.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 357613          1          2      1.0     2   1.0         2.0             1.0
# 357614          1          2      1.0     2   2.0         2.0             5.0
# 357615          2          2      1.0     2   1.0         1.0             3.0
# 357616          2          2      1.0     2   1.0         2.0             1.0
# 357617          2          2      1.0     2   2.0         2.0             4.0
#
#         vivienda_valor  acciones      monto
# 0                  3.0       1.0       0.00
# 1                  5.0       1.0       0.00
# 2                  4.0       1.0       0.00
# 3                  5.0       1.0       0.00
# 4                  3.0       2.0  678391.84
# ...                ...       ...        ...
# 357613             NaN       1.0       0.00
# 357614             NaN       1.0       0.00
# 357615             1.0       1.0   43995.00
# 357616             1.0       1.0   17134.00
# 357617             1.0       1.0  110664.00
#
# [357618 rows x 16 columns],          año  mes  cve_ent         entidad  cve_mun              minicipio  \
# 0       2017    1      NaN  No distribuido      NaN         No distribuido
# 1       2017    1      NaN  No distribuido      NaN         No distribuido
# 2       2017    1      NaN  No distribuido      NaN         No distribuido
# 3       2017    1      NaN  No distribuido      NaN         No distribuido
# 4       2017    1      1.0  Aguascalientes      1.0         Aguascalientes
# ...      ...  ...      ...             ...      ...                    ...
# 348808  2017   12     32.0       Zacatecas     58.0  Santa María de la Paz
# 348809  2017   12     32.0       Zacatecas     58.0  Santa María de la Paz
# 348810  2017   12     32.0       Zacatecas     58.0  Santa María de la Paz
# 348811  2017   12     32.0       Zacatecas     58.0  Santa María de la Paz
# 348812  2017   12     32.0       Zacatecas     58.0  Santa María de la Paz
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               4          2      1.0     1   NaN         NaN             NaN
# 1               4          4      NaN     1   NaN         NaN             NaN
# 2              10          1      2.0     2   1.0         2.0             2.0
# 3              10          1      2.0     2   2.0         2.0             1.0
# 4               1          1      2.0     2   1.0         1.0             5.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 348808          5          1     10.0     2   1.0         2.0             2.0
# 348809          5          1     10.0     2   1.0         2.0             3.0
# 348810          5          1     10.0     2   2.0         1.0             3.0
# 348811          5          1     10.0     2   2.0         2.0             3.0
# 348812          5          1     10.0     2   2.0         3.0             3.0
#
#         vivienda_valor  acciones        monto
# 0                  NaN         0  49873528.00
# 1                  NaN         0  38207676.00
# 2                  3.0         1    672750.00
# 3                  3.0         1    536250.00
# 4                  3.0         2    548045.00
# ...                ...       ...          ...
# 348808             1.0         1     66551.98
# 348809             1.0         6    399311.86
# 348810             1.0         4    266207.91
# 348811             1.0         2    133103.95
# 348812             1.0         2    133103.95
#
# [348813 rows x 16 columns],          año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0       2018    1      NaN  No distribuido      NaN  No distribuido
# 1       2018    1      NaN  No distribuido      NaN  No distribuido
# 2       2018    1      NaN  No distribuido      NaN  No distribuido
# 3       2018    1      NaN  No distribuido      NaN  No distribuido
# 4       2018    1      NaN  No distribuido      NaN  No distribuido
# ...      ...  ...      ...             ...      ...             ...
# 416779  2018   12     32.0       Zacatecas     57.0        Trancoso
# 416780  2018   12     32.0       Zacatecas     57.0        Trancoso
# 416781  2018   12     32.0       Zacatecas     57.0        Trancoso
# 416782  2018   12     32.0       Zacatecas     57.0        Trancoso
# 416783  2018   12     32.0       Zacatecas     57.0        Trancoso
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               4          1     10.0     1   NaN         NaN             NaN
# 1               4          2      1.0     1   NaN         NaN             NaN
# 2              10          1      2.0     2   1.0         2.0             1.0
# 3              10          1      2.0     2   1.0         2.0             2.0
# 4              10          1      2.0     2   1.0         2.0             2.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 416779          1          2      1.0     2   1.0         1.0             2.0
# 416780          1          2      1.0     2   1.0         1.0             4.0
# 416781          1          2      1.0     2   1.0         2.0             5.0
# 416782          2          2      1.0     2   1.0         1.0             2.0
# 416783          2          2      1.0     2   1.0         1.0             4.0
#
#         vivienda_valor  acciones        monto
# 0                  NaN       0.0  13732400.00
# 1                  NaN       0.0  91871861.99
# 2                  3.0       1.0    536000.00
# 3                  3.0       6.0   4354000.00
# 4                  4.0       7.0   6006000.00
# ...                ...       ...          ...
# 416779             NaN       1.0         0.00
# 416780             NaN       1.0         0.00
# 416781             NaN       1.0         0.00
# 416782             1.0       1.0     12453.00
# 416783             1.0       1.0     26876.00
#
# [416784 rows x 16 columns],          año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0       2021    1      NaN  No distribuido      NaN  No distribuido
# 1       2021    1      1.0  Aguascalientes      NaN  No distribuido
# 2       2021    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3       2021    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4       2021    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...      ...  ...      ...             ...      ...             ...
# 393128  2021   12     32.0       Zacatecas     57.0        Trancoso
# 393129  2021   12     32.0       Zacatecas     57.0        Trancoso
# 393130  2021   12     32.0       Zacatecas     57.0        Trancoso
# 393131  2021   12     32.0       Zacatecas     57.0        Trancoso
# 393132  2021   12     32.0       Zacatecas     57.0        Trancoso
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               4          2      1.0     1   NaN         NaN             NaN
# 1               4          2      1.0     1   NaN         NaN             NaN
# 2               1          1      2.0     2   1.0         NaN             2.0
# 3               1          1      2.0     2   1.0         NaN             2.0
# 4               1          1      2.0     2   1.0         NaN             6.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 393128          1          2      1.0     2   1.0         2.0             1.0
# 393129          1          2      1.0     2   1.0         2.0             4.0
# 393130          2          2      1.0     2   1.0         2.0             1.0
# 393131          2          2      1.0     2   1.0         2.0             3.0
# 393132          4          2      1.0     1   1.0         2.0             NaN
#
#         vivienda_valor  acciones     monto
# 0                  NaN       0.0       0.0
# 1                  NaN       0.0  287860.0
# 2                  4.0       2.0       0.0
# 3                  5.0       3.0       0.0
# 4                  4.0       2.0       0.0
# ...                ...       ...       ...
# 393128             NaN       2.0       0.0
# 393129             NaN       1.0       0.0
# 393130             1.0       2.0   53126.0
# 393131             1.0       1.0   80000.0
# 393132             NaN       1.0       0.0
#
# [393133 rows x 16 columns],          año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0       2022    1      NaN  No distribuido      NaN  No distribuido
# 1       2022    1      1.0  Aguascalientes      NaN  No distribuido
# 2       2022    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3       2022    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4       2022    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...      ...  ...      ...             ...      ...             ...
# 329843  2022   12     32.0       Zacatecas     56.0       Zacatecas
# 329844  2022   12     32.0       Zacatecas     56.0       Zacatecas
# 329845  2022   12     32.0       Zacatecas     56.0       Zacatecas
# 329846  2022   12     32.0       Zacatecas     56.0       Zacatecas
# 329847  2022   12     32.0       Zacatecas     56.0       Zacatecas
#
#         organismo  modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0               4          2      1.0     1   NaN         NaN             NaN
# 1               4          2      1.0     1   NaN         NaN             NaN
# 2               1          1      2.0     2   1.0         NaN             2.0
# 3               1          1      2.0     2   1.0         1.0             4.0
# 4               1          1      2.0     2   1.0         1.0             5.0
# ...           ...        ...      ...   ...   ...         ...             ...
# 329843          3          3      3.0     1   1.0         2.0             5.0
# 329844          3          3      3.0     1   2.0         2.0             2.0
# 329845          3          4      4.0     1   1.0         2.0             6.0
# 329846          3          4      4.0     1   2.0         2.0             2.0
# 329847          4          2      1.0     1   2.0         2.0             NaN
#
#         vivienda_valor  acciones       monto
# 0                  NaN       0.0        0.00
# 1                  NaN       0.0  1307216.96
# 2                  4.0       1.0        0.00
# 3                  3.0       1.0   245295.86
# 4                  3.0       1.0   379292.85
# ...                ...       ...         ...
# 329843             4.0       1.0  1300000.00
# 329844             3.0       2.0  1286846.81
# 329845             5.0       1.0  1200260.91
# 329846             4.0       1.0   444083.80
# 329847             NaN       1.0        0.00
#
# [329848 rows x 16 columns],        aÃ±o  mes  cve_ent         entidad  cve_mun       minicipio  organismo  \
# 0      2023    1      NaN  No distribuido      NaN  No distribuido          4
# 1      2023    1      1.0  Aguascalientes      NaN  No distribuido          4
# 2      2023    1      1.0  Aguascalientes      1.0  Aguascalientes          1
# 3      2023    1      1.0  Aguascalientes      1.0  Aguascalientes          1
# 4      2023    1      1.0  Aguascalientes      1.0  Aguascalientes          1
# ...     ...  ...      ...             ...      ...             ...        ...
# 85722  2023    4     32.0       Zacatecas     56.0       Zacatecas          3
# 85723  2023    4     32.0       Zacatecas     57.0        Trancoso          1
# 85724  2023    4     32.0       Zacatecas     57.0        Trancoso          1
# 85725  2023    4     32.0       Zacatecas     57.0        Trancoso          1
# 85726  2023    4     32.0       Zacatecas     57.0        Trancoso          2
#
#        modalidad  destino  tipo  sexo  edad_rango  ingresos_rango  \
# 0              2      1.0     1   NaN         NaN             NaN
# 1              2      1.0     1   NaN         NaN             NaN
# 2              1      2.0     2   1.0         NaN             1.0
# 3              1      2.0     2   1.0         NaN             1.0
# 4              1      2.0     2   1.0         NaN             1.0
# ...          ...      ...   ...   ...         ...             ...
# 85722          3      3.0     1   1.0         2.0             5.0
# 85723          2      1.0     2   1.0         2.0             1.0
# 85724          2      1.0     2   2.0         2.0             2.0
# 85725          2      1.0     2   2.0         2.0             3.0
# 85726          2      1.0     1   2.0         2.0             1.0
#
#        vivienda_valor  acciones       monto
# 0                 NaN         0        0.00
# 1                 NaN         0  1158580.13
# 2                 2.0         1        0.00
# 3                 3.0         4        0.00
# 4                 4.0         1        0.00
# ...               ...       ...         ...
# 85722             4.0         2  1900000.00
# 85723             NaN         1        0.00
# 85724             NaN         1        0.00
# 85725             NaN         1        0.00
# 85726             1.0         2    86511.00
#
# [85727 rows x 16 columns]]
# Data converted to Parquet format and saved as merged_data.parquet

# %%
db=pd.read_parquet("/content/merged_data.parquet")

db
# Out:
#             año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0        2019.0    1      1.0  Aguascalientes      NaN  No distribuido
# 1        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 2        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...         ...  ...      ...             ...      ...             ...
# 2315291     NaN    4     32.0       Zacatecas     56.0            None
# 2315292     NaN    4     32.0       Zacatecas     57.0            None
# 2315293     NaN    4     32.0       Zacatecas     57.0            None
# 2315294     NaN    4     32.0       Zacatecas     57.0            None
# 2315295     NaN    4     32.0       Zacatecas     57.0            None
#
#          organismo  modalidad  destino  tipo  sexo  edad_rango  \
# 0                4          2      1.0     1   NaN         NaN
# 1                1          1      2.0     2   1.0         NaN
# 2                1          1      2.0     2   1.0         NaN
# 3                1          1      2.0     2   1.0         NaN
# 4                1          1      2.0     2   1.0         NaN
# ...            ...        ...      ...   ...   ...         ...
# 2315291          3          3      3.0     1   1.0         2.0
# 2315292          1          2      1.0     2   1.0         2.0
# 2315293          1          2      1.0     2   2.0         2.0
# 2315294          1          2      1.0     2   2.0         2.0
# 2315295          2          2      1.0     1   2.0         2.0
#
#          ingresos_rango  vivienda_valor  acciones      monto  minicipio  \
# 0                   NaN             NaN       0.0    96860.0       None
# 1                   1.0             4.0       4.0        0.0       None
# 2                   2.0             3.0       1.0        0.0       None
# 3                   3.0             4.0       1.0        0.0       None
# 4                   4.0             4.0       1.0        0.0       None
# ...                 ...             ...       ...        ...        ...
# 2315291             5.0             4.0       2.0  1900000.0  Zacatecas
# 2315292             1.0             NaN       1.0        0.0   Trancoso
# 2315293             2.0             NaN       1.0        0.0   Trancoso
# 2315294             3.0             NaN       1.0        0.0   Trancoso
# 2315295             1.0             1.0       2.0    86511.0   Trancoso
#
#            aÃ±o
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2315291  2023.0
# 2315292  2023.0
# 2315293  2023.0
# 2315294  2023.0
# 2315295  2023.0
#
# [2315296 rows x 18 columns]

# %% [markdown]
# # Llenar un columna con datos vacios de otra

# %%
db.describe()
# Out:
#                 año           mes       cve_ent       cve_mun     organismo  \
# count  2.229569e+06  2.315296e+06  2.314990e+06  2.310658e+06  2.315296e+06
# mean   2.019457e+03  6.698356e+00  1.662320e+01  4.327088e+01  2.040924e+00
# std    1.673627e+00  3.427975e+00  8.367111e+00  5.346035e+01  1.936413e+00
# min    2.017000e+03  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.018000e+03  4.000000e+00  1.000000e+01  1.000000e+01  1.000000e+00
# 50%    2.019000e+03  7.000000e+00  1.500000e+01  2.700000e+01  2.000000e+00
# 75%    2.021000e+03  1.000000e+01  2.300000e+01  5.400000e+01  2.000000e+00
# max    2.022000e+03  1.200000e+01  3.200000e+01  5.700000e+02  2.600000e+01
#
#           modalidad       destino          tipo          sexo    edad_rango  \
# count  2.315296e+06  2.307319e+06  2.315296e+06  2.302037e+06  2.272656e+06
# mean   2.019879e+00  2.307388e+00  1.372196e+00  1.425450e+00  1.800512e+00
# std    8.984140e-01  1.591711e+00  4.833903e-01  4.944112e-01  5.160368e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 50%    2.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 75%    3.000000e+00  3.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# max    4.000000e+00  1.800000e+01  2.000000e+00  2.000000e+00  3.000000e+00
#
#        ingresos_rango  vivienda_valor      acciones         monto     aÃ±o
# count    2.224333e+06    1.877622e+06  2.315296e+06  2.315296e+06  85727.0
# mean     3.279109e+00    2.979838e+00  2.810308e+00  1.123629e+06   2023.0
# std      1.747322e+00    1.354455e+00  2.579043e+01  7.059333e+06      0.0
# min      1.000000e+00    1.000000e+00  0.000000e+00 -4.246328e+05   2023.0
# 25%      2.000000e+00    2.000000e+00  1.000000e+00  5.140500e+04   2023.0
# 50%      3.000000e+00    3.000000e+00  1.000000e+00  4.673786e+05   2023.0
# 75%      5.000000e+00    4.000000e+00  2.000000e+00  1.080409e+06   2023.0
# max      6.000000e+00    6.000000e+00  3.215300e+04  7.854406e+09   2023.0

# %%
#valores_nulos = db.isnull().mean() * 100
#valores_nulos

valores_nulos = db.isnull().sum()
porcentajes_nulos = valores_nulos / db.shape[0] * 100
porcentajes_nulos_ordenados = porcentajes_nulos.sort_values(ascending=False)
porcentajes_nulos_ordenados
# Out:
# aÃ±o              96.297363
# minicipio         81.231773
# vivienda_valor    18.903587
# municipio         18.768227
# ingresos_rango     3.928785
# año                3.702637
# edad_rango         1.841665
# sexo               0.572670
# destino            0.344535
# cve_mun            0.200320
# cve_ent            0.013216
# organismo          0.000000
# modalidad          0.000000
# mes                0.000000
# entidad            0.000000
# acciones           0.000000
# monto              0.000000
# tipo               0.000000
# dtype: float64

# %%
db['municipio'] = db['municipio'].fillna(db['minicipio'])
db['año'] = db['año'].fillna(db['aÃ±o'])
db.drop(['aÃ±o','minicipio'], axis=1, inplace=True)
db
# Out:
#             año  mes  cve_ent         entidad  cve_mun       municipio  \
# 0        2019.0    1      1.0  Aguascalientes      NaN  No distribuido
# 1        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 2        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 3        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# 4        2019.0    1      1.0  Aguascalientes      1.0  Aguascalientes
# ...         ...  ...      ...             ...      ...             ...
# 2315291  2023.0    4     32.0       Zacatecas     56.0       Zacatecas
# 2315292  2023.0    4     32.0       Zacatecas     57.0        Trancoso
# 2315293  2023.0    4     32.0       Zacatecas     57.0        Trancoso
# 2315294  2023.0    4     32.0       Zacatecas     57.0        Trancoso
# 2315295  2023.0    4     32.0       Zacatecas     57.0        Trancoso
#
#          organismo  modalidad  destino  tipo  sexo  edad_rango  \
# 0                4          2      1.0     1   NaN         NaN
# 1                1          1      2.0     2   1.0         NaN
# 2                1          1      2.0     2   1.0         NaN
# 3                1          1      2.0     2   1.0         NaN
# 4                1          1      2.0     2   1.0         NaN
# ...            ...        ...      ...   ...   ...         ...
# 2315291          3          3      3.0     1   1.0         2.0
# 2315292          1          2      1.0     2   1.0         2.0
# 2315293          1          2      1.0     2   2.0         2.0
# 2315294          1          2      1.0     2   2.0         2.0
# 2315295          2          2      1.0     1   2.0         2.0
#
#          ingresos_rango  vivienda_valor  acciones      monto
# 0                   NaN             NaN       0.0    96860.0
# 1                   1.0             4.0       4.0        0.0
# 2                   2.0             3.0       1.0        0.0
# 3                   3.0             4.0       1.0        0.0
# 4                   4.0             4.0       1.0        0.0
# ...                 ...             ...       ...        ...
# 2315291             5.0             4.0       2.0  1900000.0
# 2315292             1.0             NaN       1.0        0.0
# 2315293             2.0             NaN       1.0        0.0
# 2315294             3.0             NaN       1.0        0.0
# 2315295             1.0             1.0       2.0    86511.0
#
# [2315296 rows x 16 columns]

# %% [markdown]
# # Re ordenar las columnas de acuerdo orden original

# %%
column_order = ['año', 'municipio', 'mes', 'cve_ent', 'entidad', 'cve_mun', 'organismo', 'modalidad', 'destino', 'tipo', 'sexo', 'edad_rango', 'ingresos_rango', 'vivienda_valor', 'acciones', 'monto']

db = db.reindex(columns=column_order)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2315296 entries, 0 to 2315295
# Data columns (total 16 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   año             float64
#  1   municipio       object
#  2   mes             int64
#  3   cve_ent         float64
#  4   entidad         object
#  5   cve_mun         float64
#  6   organismo       int64
#  7   modalidad       int64
#  8   destino         float64
#  9   tipo            int64
#  10  sexo            float64
#  11  edad_rango      float64
#  12  ingresos_rango  float64
#  13  vivienda_valor  float64
#  14  acciones        float64
#  15  monto           float64
# dtypes: float64(10), int64(4), object(2)
# memory usage: 282.6+ MB

# %% [markdown]
# # Diccionario
#
# Para reemplazar los códigos de rango de edad con sus descripciones correspondientes en la columna 'edad_rango', puedes utilizar el método replace de pandas. Aquí tienes un ejemplo de cómo hacerlo

# %%
age_dict = {
    1: '29 o menos',
    2: '30 a 59',
    3: '60 o más',
    4: 'No especificado'
}

db['edad_rango'] = db['edad_rango'].replace(age_dict)
db.edad_rango
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 2315291    30 a 59
# 2315292    30 a 59
# 2315293    30 a 59
# 2315294    30 a 59
# 2315295    30 a 59
# Name: edad_rango, Length: 2315296, dtype: object

# %%
# Supongamos que 'merged_df' es el dataframe combinado
income_dict = {
    1: '2.6 o menos',
    2: '2.61 a 4.00',
    3: '4.01 a 6.00',
    4: '6.01 a 9.00',
    5: '9.01 a 12.00',
    6: 'Más de 12',
    7: 'No especificado'
}

# Reemplazar los códigos de rango de ingresos con las descripciones correspondientes
db['ingresos_rango'] = db['ingresos_rango'].replace(income_dict)

# Imprimir el dataframe actualizado
print(db)
# Out:
#             año       municipio  mes  cve_ent         entidad  cve_mun  \
# 0        2019.0  No distribuido    1      1.0  Aguascalientes      NaN
# 1        2019.0  Aguascalientes    1      1.0  Aguascalientes      1.0
# 2        2019.0  Aguascalientes    1      1.0  Aguascalientes      1.0
# 3        2019.0  Aguascalientes    1      1.0  Aguascalientes      1.0
# 4        2019.0  Aguascalientes    1      1.0  Aguascalientes      1.0
# ...         ...             ...  ...      ...             ...      ...
# 2315291  2023.0       Zacatecas    4     32.0       Zacatecas     56.0
# 2315292  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315293  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315294  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315295  2023.0        Trancoso    4     32.0       Zacatecas     57.0
#
#          organismo  modalidad  destino  tipo  sexo edad_rango ingresos_rango  \
# 0                4          2      1.0     1   NaN        NaN            NaN
# 1                1          1      2.0     2   1.0        NaN    2.6 o menos
# 2                1          1      2.0     2   1.0        NaN    2.61 a 4.00
# 3                1          1      2.0     2   1.0        NaN    4.01 a 6.00
# 4                1          1      2.0     2   1.0        NaN    6.01 a 9.00
# ...            ...        ...      ...   ...   ...        ...            ...
# 2315291          3          3      3.0     1   1.0    30 a 59   9.01 a 12.00
# 2315292          1          2      1.0     2   1.0    30 a 59    2.6 o menos
# 2315293          1          2      1.0     2   2.0    30 a 59    2.61 a 4.00
# 2315294          1          2      1.0     2   2.0    30 a 59    4.01 a 6.00
# 2315295          2          2      1.0     1   2.0    30 a 59    2.6 o menos
#
#          vivienda_valor  acciones      monto
# 0                   NaN       0.0    96860.0
# 1                   4.0       4.0        0.0
# 2                   3.0       1.0        0.0
# 3                   4.0       1.0        0.0
# 4                   4.0       1.0        0.0
# ...                 ...       ...        ...
# 2315291             4.0       2.0  1900000.0
# 2315292             NaN       1.0        0.0
# 2315293             NaN       1.0        0.0
# 2315294             NaN       1.0        0.0
# 2315295             1.0       2.0    86511.0
#
# [2315296 rows x 16 columns]

# %% [markdown]
# Para reemplazar los códigos de valor de vivienda con sus descripciones correspondientes en la columna 'vivienda_valor', puedes utilizar el método replace de pandas. Aquí tienes un ejemplo de cómo hacerlo:

# %%
housing_dict = {
    1: 'Económica',
    2: 'Popular',
    3: 'Tradicional',
    4: 'Media',
    5: 'Residencial',
    6: 'Residencial plus',
    7: 'No especificado'
}

db['vivienda_valor'] = db['vivienda_valor'].replace(housing_dict)

print(db)
# Out:
#             año       municipio  mes  cve_ent         entidad  cve_mun  \
# 0        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 1        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 2        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 3        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 4        2018.0  No distribuido    1      NaN  No distribuido      NaN
# ...         ...             ...  ...      ...             ...      ...
# 2315291  2023.0       Zacatecas    4     32.0       Zacatecas     56.0
# 2315292  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315293  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315294  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315295  2023.0        Trancoso    4     32.0       Zacatecas     57.0
#
#          organismo  modalidad  destino  tipo  sexo edad_rango ingresos_rango  \
# 0                4          1     10.0     1   NaN        NaN            NaN
# 1                4          2      1.0     1   NaN        NaN            NaN
# 2               10          1      2.0     2   1.0    30 a 59    2.6 o menos
# 3               10          1      2.0     2   1.0    30 a 59    2.61 a 4.00
# 4               10          1      2.0     2   1.0    30 a 59    2.61 a 4.00
# ...            ...        ...      ...   ...   ...        ...            ...
# 2315291          3          3      3.0     1   1.0    30 a 59   9.01 a 12.00
# 2315292          1          2      1.0     2   1.0    30 a 59    2.6 o menos
# 2315293          1          2      1.0     2   2.0    30 a 59    2.61 a 4.00
# 2315294          1          2      1.0     2   2.0    30 a 59    4.01 a 6.00
# 2315295          2          2      1.0     1   2.0    30 a 59    2.6 o menos
#
#         vivienda_valor  acciones        monto
# 0                  NaN       0.0  13732400.00
# 1                  NaN       0.0  91871861.99
# 2          Tradicional       1.0    536000.00
# 3          Tradicional       6.0   4354000.00
# 4                Media       7.0   6006000.00
# ...                ...       ...          ...
# 2315291          Media       2.0   1900000.00
# 2315292            NaN       1.0         0.00
# 2315293            NaN       1.0         0.00
# 2315294            NaN       1.0         0.00
# 2315295      Económica       2.0     86511.00
#
# [2315296 rows x 16 columns]

# %%
organism_dict = {
    1: "INFONAVIT",
    2: "CNBV",
    3: "FOVISSSTE",
    4: "SHF",
    5: "CONAVI",
    6: "INVI",
    7: "Banjercito",
    8: "Hábitat México",
    9: "CFE",
    10: "ISSFAM",
    11: "PEMEX",
    12: "FONHAPO",
    13: "PDZP SEDESOL",
    14: "SOFOLES AMFE",
    15: "ISSSTELEON",
    16: "INDIVI",
    17: "COVEG",
    18: "COESVI",
    19: "IMEVIS",
    20: "IVEM",
    21: "ITAVU",
    22: "IVNL",
    23: "INVIVIENDA",
    24: "IVEY",
    25: "INFOVIR",
    26: "Instituto Nacional del Suelo Sustentable"
}

db['organismo'].replace(organism_dict, inplace=True)

print(db)
# Out:
#             año       municipio  mes  cve_ent         entidad  cve_mun  \
# 0        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 1        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 2        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 3        2018.0  No distribuido    1      NaN  No distribuido      NaN
# 4        2018.0  No distribuido    1      NaN  No distribuido      NaN
# ...         ...             ...  ...      ...             ...      ...
# 2315291  2023.0       Zacatecas    4     32.0       Zacatecas     56.0
# 2315292  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315293  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315294  2023.0        Trancoso    4     32.0       Zacatecas     57.0
# 2315295  2023.0        Trancoso    4     32.0       Zacatecas     57.0
#
#          organismo  modalidad  destino  tipo  sexo edad_rango ingresos_rango  \
# 0              SHF          1     10.0     1   NaN        NaN            NaN
# 1              SHF          2      1.0     1   NaN        NaN            NaN
# 2           ISSFAM          1      2.0     2   1.0    30 a 59    2.6 o menos
# 3           ISSFAM          1      2.0     2   1.0    30 a 59    2.61 a 4.00
# 4           ISSFAM          1      2.0     2   1.0    30 a 59    2.61 a 4.00
# ...            ...        ...      ...   ...   ...        ...            ...
# 2315291  FOVISSSTE          3      3.0     1   1.0    30 a 59   9.01 a 12.00
# 2315292  INFONAVIT          2      1.0     2   1.0    30 a 59    2.6 o menos
# 2315293  INFONAVIT          2      1.0     2   2.0    30 a 59    2.61 a 4.00
# 2315294  INFONAVIT          2      1.0     2   2.0    30 a 59    4.01 a 6.00
# 2315295       CNBV          2      1.0     1   2.0    30 a 59    2.6 o menos
#
#         vivienda_valor  acciones        monto
# 0                  NaN       0.0  13732400.00
# 1                  NaN       0.0  91871861.99
# 2          Tradicional       1.0    536000.00
# 3          Tradicional       6.0   4354000.00
# 4                Media       7.0   6006000.00
# ...                ...       ...          ...
# 2315291          Media       2.0   1900000.00
# 2315292            NaN       1.0         0.00
# 2315293            NaN       1.0         0.00
# 2315294            NaN       1.0         0.00
# 2315295      Económica       2.0     86511.00
#
# [2315296 rows x 16 columns]

# %% [markdown]
# Graficar con m

# %%
db.to_csv("data.csv")
db.head(10)
db.shape
# Out:
# (2315296, 16)

# %% [markdown]
# ---
# # Haz un histograma de la columna 'año'

# %%
import matplotlib.pyplot as plt

# Haz un histograma de la columna 'año'
db['año'].hist(bins=30, edgecolor='black')

# Añade títulos y etiquetas
plt.title('Histograma de Años')
plt.xlabel('Año')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
print(db['organismo'].value_counts())
db['organismo'].value_counts().plot(kind='line')
plt.title('Número de Acciones por Organismo')
plt.xlabel('Organismo')
plt.ylabel('Número de Acciones')
plt.show()
# Out:
# INFONAVIT                                   1131684
# CNBV                                         713844
# FOVISSSTE                                    211375
# SHF                                          125001
# CONAVI                                        72172
# FONHAPO                                       27759
# CFE                                            8517
# INVI                                           8347
# ISSFAM                                         4807
# Banjercito                                     4282
# Instituto Nacional del Suelo Sustentable       4021
# Hábitat México                                 3269
# PEMEX                                           218
# Name: organismo, dtype: int64

# %%
data_grouped = db.groupby('año')['monto'].mean().plot(kind='line',marker='o')

# Dibuja el gráfico de líneas

print(data_grouped)
#plt.plot(data_grouped.index, data_grouped.values, marker='o')

# Añade títulos y etiquetas
plt.title('Cambio en el Monto a lo largo de los Años')
plt.xlabel('Año')
plt.ylabel('Monto Promedio')


plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
db.shape
# Out:
# (2315296, 16)

# %% [markdown]
# # Se duplico el gasto de costo de vivienda
